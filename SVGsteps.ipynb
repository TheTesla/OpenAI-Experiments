# %%
from gptapilib import ChatBot, printmd
from IPython.display import SVG, display


gen = ChatBot("You are a very creative vector graphics artist! Many details! Output valid SVG code only! Don't output codeblock formatation!")
chk = ChatBot("Du überprüfst den SVG Code under versuchst leitest den Gesprächsparter an eine bessere SVG Grafik zu erzeugen!")

a = "Frage deinen Gesprächspartner nach einem sehr hochwertigen SVG, das eine Ente und einen Schwan auf einem See zeigen. Verbessere ihnen Schritt für Schritt."

for i in range(3):
    q = chk.ask(a)
    printmd(f"# CHK \n {q}")
    a = gen.ask(q)
    display(SVG(a))
    #printmd(f"# GEN \n {a}")
# Out:
# # CHK
#  Natürlich, ich helfe dir gerne dabei, eine hochwertige SVG-Grafik zu erstellen, die eine Ente und einen Schwan auf einem See zeigt. Lass uns Schritt für Schritt vorgehen. Zunächst benötigen wir die grundlegenden Elemente der Grafik:
#
# 1. **See**: Ein einfaches Rechteck oder eine komplexere Form, die das Wasser darstellt.
# 2. **Ente**: Eine Form, die eine Ente repräsentiert.
# 3. **Schwan**: Eine Form, die einen Schwan repräsentiert.
#
# Hier ist ein grundlegender SVG-Code, der diese Elemente enthält. Wir werden diesen Code schrittweise verbessern.
#
# ```svg
# <svg width="400" height="400" xmlns="http://www.w3.org/2000/svg">
#   <!-- Der See -->
#   <rect x="0" y="200" width="400" height="200" fill="lightblue" />
#
#   <!-- Die Ente -->
#   <ellipse cx="100" cy="250" rx="30" ry="20" fill="yellow" />
#   <circle cx="130" cy="240" r="10" fill="yellow" />
#   <circle cx="135" cy="235" r="2" fill="black" />
#   <polygon points="140,240 150,235 140,230" fill="orange" />
#
# ...
